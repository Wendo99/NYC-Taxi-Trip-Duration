# %% [markdown]
# # Load & Merge Data

# %%
# Load packages
import pandas as pd

# %%
# Load taxi and weather data
taxi_data_clean = pd.read_csv("data/taxi_data_clean.csv")
weather_data_clean = pd.read_csv("data/weather_data_clean.csv")

# %%
# Merge taxi and weather data
taxi_weather_data_raw = pd.merge(taxi_data_clean, weather_data_clean, how='inner',
                               on=['hour_of_year'])

# %%
taxi_weather_data_raw
# Out:
#                 id  vendor_id      pickup_datetime     dropoff_datetime  \
# 0        id2875421          2  2016-03-14 17:24:55  2016-03-14 17:32:30
# 1        id2377394          1  2016-06-12 00:43:35  2016-06-12 00:54:38
# 2        id3858529          2  2016-01-19 11:35:24  2016-01-19 12:10:48
# 3        id3504673          2  2016-04-06 19:32:31  2016-04-06 19:39:40
# 4        id2181028          2  2016-03-26 13:30:55  2016-03-26 13:38:10
# ...            ...        ...                  ...                  ...
# 1408168  id2376096          2  2016-04-08 13:31:04  2016-04-08 13:44:02
# 1408169  id1049543          1  2016-01-10 07:35:15  2016-01-10 07:46:10
# 1408170  id2304944          2  2016-04-22 06:57:41  2016-04-22 07:10:25
# 1408171  id2714485          1  2016-01-05 15:56:26  2016-01-05 16:02:39
# 1408172  id1209952          1  2016-04-05 14:44:25  2016-04-05 14:47:43
#
#          passenger_count  pickup_longitude  pickup_latitude  \
# 0                      1        -73.982155        40.767937
# 1                      1        -73.980415        40.738564
# 2                      1        -73.979027        40.763939
# 3                      1        -74.010040        40.719971
# 4                      1        -73.973053        40.793209
# ...                  ...               ...              ...
# 1408168                4        -73.982201        40.745522
# 1408169                1        -74.000946        40.747379
# 1408170                1        -73.959129        40.768799
# 1408171                1        -73.982079        40.749062
# 1408172                1        -73.979538        40.781750
#
#          dropoff_longitude  dropoff_latitude store_and_fwd_flag  ...  \
# 0               -73.964630         40.765602                  N  ...
# 1               -73.999481         40.731152                  N  ...
# 2               -74.005333         40.710087                  N  ...
# 3               -74.012268         40.706718                  N  ...
# 4               -73.972923         40.782520                  N  ...
# ...                    ...               ...                ...  ...
# 1408168         -73.994911         40.740170                  N  ...
# 1408169         -73.970184         40.796547                  N  ...
# 1408170         -74.004433         40.707371                  N  ...
# 1408171         -73.974632         40.757107                  N  ...
# 1408172         -73.972809         40.790585                  N  ...
#
#          fog_class  fog_class_code  temp_class  temp_class_code  \
# 0           no fog               0        cool                2
# 1           no fog               0         hot                5
# 2           no fog               0        cold                1
# 3           no fog               0        cool                2
# 4           no fog               0        cool                2
# ...            ...             ...         ...              ...
# 1408168     no fog               0        cool                2
# 1408169     no fog               0        cool                2
# 1408170     no fog               0        mild                3
# 1408171     no fog               0        cold                1
# 1408172     no fog               0        cold                1
#
#          windspeed_class  windspeed_class_code  humidity_class  \
# 0           light breeze                     2        very_wet
# 1              light air                     1          normal
# 2           light breeze                     2             dry
# 3           light breeze                     2          normal
# 4              light air                     1             dry
# ...                  ...                   ...             ...
# 1408168     light breeze                     2             dry
# 1408169     light breeze                     2        very_wet
# 1408170        light air                     1          normal
# 1408171        light air                     1        very_dry
# 1408172        light air                     1        very_dry
#
#          humidity_class_code  pressure_class pressure_class_code
# 0                          4          normal                   2
# 1                          2          normal                   2
# 2                          1          normal                   2
# 3                          2          normal                   2
# 4                          1            high                   3
# ...                      ...             ...                 ...
# 1408168                    1          normal                   2
# 1408169                    4          normal                   2
# 1408170                    2          normal                   2
# 1408171                    0       very high                   4
# 1408172                    0            high                   3
#
# [1408173 rows x 59 columns]
